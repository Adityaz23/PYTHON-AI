# %% [markdown]
# <a href="https://colab.research.google.com/github/Adityaz23/PYTHON-AI/blob/main/CS50.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #This is the course of python from CS50

# %%
# There are two ways to write the funcitons ->
# name = input("What is your name? ").strip().title() # strip is used to remove all the faltu ki spaces and title is used to make the first letter capital just like a author name
# print("Hello",name)
# Now spliting the name as the firstname and lastname ->
# first, last = name.split(" ")
# this will split the full name and last name as two different properties ->
# print(f"First name: {first}")
# same for the lastname ->
# print(f"Last name: {last}")
# full name =>
# print(f"Full Name: {name}")
# another way to print the statement is called fromat print statement ->
# print(f"Hello, {name}")

# Int ->
# x = int(input("What is x? "))
# y = int(input("What is y? "))
# z = print(f"z =",x+y)

# Float -> Float are used to have decimal point of a number
# a = float(input("a =  "))
# b = float(input("b =  "))
# c = print(f"c =",round(a+b)) # this will give us the over all value like the round of.Ex- 1.2+2.3 = 4 not 3.5

d = float(input("d = "))
e = float(input("e = "))
# f = print(f"f =",round(d/e)) # this will also give us the round value.
f = d/e
# print(f"{f}") # this is the output of this function now let's use round off like how many decimal point value we need
# d = 2
# e = 3
# 0.6666666666666666

print(f"{f:.2f}") # this .2f will be decimal point which we will get the value till
# d = 2
# e = 3
# 0.67
# Out:
# d = 2
# e = 3
# 0.67

# %%
# function call ->
# def hello():
  # name = input("What is your name? ").title().strip()
  # print(f"Name is:",name)
# hello()

def main():
  x = int(input("x is = "))
  print(f"x is squared: ",squares(x))

def squares(n):
  return n * n

main()
# Out:
# x is = 3
# x is squared:  9

# %%
# # Conditionals -> Use to compare values
# x = int(input("Enter x: "))
# y = int(input("Enter y: "))

# if x < y:
#   print("X is lesser than y")
# if x > y:
#   print("Y is lesser than x")
# if x == y:
#   print("x and y both are equals")
# else:
#   print("Invalid inputs")

# another way to write the same code but not repeating if statement ->
# x = int(input("Enter x: "))
# y = int(input("Enter y: "))

# grading system ->
# grades = int(input("Enter your marks: "))
# if grades >= 90 and grades <=100:
  # print("A")
# elif grades >= 80 and grades <=90:
  # print("B")
# elif grades >=70 and grades <=80:
  # print("C")
# elif grades >=60 and grades <=70:
  # print("D")
# else:
  # print("F")

# def main():
  # a = int(input("What is a: "))
  # if is_even(a):
    # print("Even")
  # else:
    # print("ODD")
#
# def is_even(n):
  # if n % 2 == 0:
    # return True

# main()

name = input("What is your name? ")
if name == "Harry":
  print("Red")
elif name == "Ron":
  print("Red")
elif name == "Hermoine":
  print("Red")
elif name == "Draco":
  print("Blue")
else:
  print("Who ?")
# Out:
# What is your name? Ron
# Red
